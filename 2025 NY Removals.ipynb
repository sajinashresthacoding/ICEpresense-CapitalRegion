# %% [markdown]
# ### In this notebook I will:
# pull data from Removals the year 2025

# %%
## import necessary libraries
import pandas as pd

# %%
from datetime import datetime

# %%
df1 = pd.read_excel('/Users/sajinashrestha/Documents/dataProjects/WAMC/ICEpresense-CapitalRegion/RawData/Removals/2026-ICLI-00005_Removals_FY25_20260311_Redacted.xlsx')
df1
# Out:
#                        ERO LESA Statistical Tracking Unit        Unnamed: 1  \
# 0             For Official Use Only (FOUO)/Pre-decisional               NaN
# 1       Deportation Data Project - 2026-ICLI-00005 – 0...               NaN
# 2                                                     NaN               NaN
# 3                                                     NaN               NaN
# 4                                     ICE Removals FY2025               NaN
# ...                                                   ...               ...
# 367408                                2025-09-30 00:00:00   LAREDO, TX, POE
# 367409                                2025-09-30 00:00:00   LAREDO, TX, POE
# 367410                                2025-09-30 00:00:00   LAREDO, TX, POE
# 367411                                2025-09-30 00:00:00   LAREDO, TX, POE
# 367412                                2024-12-23 00:00:00  HIDALGO, TX, POE
#
# ...

# %%
df1 = df1.iloc[5:]
df1
# Out:
#        ERO LESA Statistical Tracking Unit  \
# 5                           Departed Date
# 6                     2024-12-27 00:00:00
# 7                     2025-07-25 00:00:00
# 8                     2025-09-24 00:00:00
# 9                     2024-12-07 00:00:00
# ...                                   ...
# 367408                2025-09-30 00:00:00
# 367409                2025-09-30 00:00:00
# 367410                2025-09-30 00:00:00
# 367411                2025-09-30 00:00:00
# 367412                2024-12-23 00:00:00
#
#                                    Unnamed: 1         Unnamed: 2  \
# 5                           Port of Departure  Departure Country
# 6                            NOGALES, AZ, POE             MEXICO
# 7       ALEXANDRIA INTERNATIONAL AIRPORT, POE           HONDURAS
# 8       ALEXANDRIA INTERNATIONAL AIRPORT, POE          GUATEMALA
# 9                        LOS ANGELES, CA, POE        EL SALVADOR
# ...

# %%
df1.columns = df1.iloc[0]
df1_titled = df1[1:].reset_index(drop=True)
df1_titled
# Out:
# 5             Departed Date                      Port of Departure  \
# 0       2024-12-27 00:00:00                       NOGALES, AZ, POE
# 1       2025-07-25 00:00:00  ALEXANDRIA INTERNATIONAL AIRPORT, POE
# 2       2025-09-24 00:00:00  ALEXANDRIA INTERNATIONAL AIRPORT, POE
# 3       2024-12-07 00:00:00                   LOS ANGELES, CA, POE
# 4       2025-07-05 00:00:00                       ORLANDO, FL, POE
# ...                     ...                                    ...
# 367402  2025-09-30 00:00:00                        LAREDO, TX, POE
# 367403  2025-09-30 00:00:00                        LAREDO, TX, POE
# 367404  2025-09-30 00:00:00                        LAREDO, TX, POE
# 367405  2025-09-30 00:00:00                        LAREDO, TX, POE
# 367406  2024-12-23 00:00:00                       HIDALGO, TX, POE
#
# 5      Departure Country                            Case AOR    State County  \
# 0                 MEXICO      Phoenix Area of Responsibility      NaN    NaN
# ...

# %%
df1_titled['Departed Date'] = pd.to_datetime(df1_titled['Departed Date'])

# %%
dfRemovals1 = df1_titled.loc[
  (df1_titled["Departed Date"] >= "2025-01-01") &
  (df1_titled["Departed Date"] <= "2025-12-31")
]

# %%
dfRemovals1
# Out:
# Empty DataFrame
# Columns: [Departed Date, Port of Departure, Departure Country, Case AOR, State, County, Case Status, Gender, Birth Country, Citizenship Country, Birth Date, Birth Year, Entry Date, Entry Status, Known Terrorist Yes No, Suspected Gang Yes No, MSC Charge, MSC Charge Date, MSC Criminal Charge Status, MSC Charge Code, MSC Conviction Date, Case Criminality, Case Threat Level, Aggravated Felon Yes No, Processing Disposition, Case Category, Final Program, Final Program Code, Arresting Agency, TOA Case Category, Latest Apprehension Final Program, Latest Arresting Agency, Latest Apprehension Date, Final Order Yes No, Final Order Date, Final Charge Code, Final Charge Section, Prior Deport Yes No, Anonymized Identifier]
# Index: []
#
# [0 rows x 39 columns]

# %%
dfArrests1.to_csv('FilteredData/2025ICEArrests1.csv', index=False)

# %%
df2 = pd.read_excel('/Users/sajinashrestha/Documents/dataProjects/WAMC/ICEpresense-CapitalRegion/RawData/Removals/2026-ICLI-00005_Removals_FY26_20260311_Redacted.xlsx')
df2
# Out:
#                        ERO LESA Statistical Tracking Unit       Unnamed: 1  \
# 0             For Official Use Only (FOUO)/Pre-decisional              NaN
# 1       Deportation Data Project - 2026-ICLI-00005 – 0...              NaN
# 2                                                     NaN              NaN
# 3                                                     NaN              NaN
# 4           ICE Removals FY2026 (10/01/2025 - 03/10/2026)              NaN
# ...                                                   ...              ...
# 191269                                2026-03-10 00:00:00  LAREDO, TX, POE
# 191270                                2026-03-10 00:00:00  LAREDO, TX, POE
# 191271                                2026-03-10 00:00:00  LAREDO, TX, POE
# 191272                                2026-03-10 00:00:00  LAREDO, TX, POE
# 191273                                2026-03-10 00:00:00  LAREDO, TX, POE
#
# ...

# %%
df2 = df2.iloc[5:]
df2
# Out:
#        ERO LESA Statistical Tracking Unit  \
# 5                           Departed Date
# 6                     2025-11-28 00:00:00
# 7                     2025-11-13 00:00:00
# 8                     2025-12-10 00:00:00
# 9                     2025-12-02 00:00:00
# ...                                   ...
# 191269                2026-03-10 00:00:00
# 191270                2026-03-10 00:00:00
# 191271                2026-03-10 00:00:00
# 191272                2026-03-10 00:00:00
# 191273                2026-03-10 00:00:00
#
#                                    Unnamed: 1         Unnamed: 2  \
# 5                           Port of Departure  Departure Country
# 6                            PHOENIX, AZ, POE          VENEZUELA
# 7       ALEXANDRIA INTERNATIONAL AIRPORT, POE           COLOMBIA
# 8               LOS ANGELES, CA, AIRPORT, POE            TURKIYE
# 9       ALEXANDRIA INTERNATIONAL AIRPORT, POE           COLOMBIA
# ...

# %%
df2.columns = df2.iloc[0]
df2_titled = df2[1:].reset_index(drop=True)
df2_titled
# Out:
# 5             Departed Date                      Port of Departure  \
# 0       2025-11-28 00:00:00                       PHOENIX, AZ, POE
# 1       2025-11-13 00:00:00  ALEXANDRIA INTERNATIONAL AIRPORT, POE
# 2       2025-12-10 00:00:00          LOS ANGELES, CA, AIRPORT, POE
# 3       2025-12-02 00:00:00  ALEXANDRIA INTERNATIONAL AIRPORT, POE
# 4       2025-12-20 00:00:00                       NOGALES, AZ, POE
# ...                     ...                                    ...
# 191263  2026-03-10 00:00:00                        LAREDO, TX, POE
# 191264  2026-03-10 00:00:00                        LAREDO, TX, POE
# 191265  2026-03-10 00:00:00                        LAREDO, TX, POE
# 191266  2026-03-10 00:00:00                        LAREDO, TX, POE
# 191267  2026-03-10 00:00:00                        LAREDO, TX, POE
#
# 5      Departure Country                               Case AOR  State County  \
# 0              VENEZUELA     San Antonio Area of Responsibility    NaN    NaN
# ...

# %%
df2_titled['Departed Date'] = pd.to_datetime(df2_titled['Departed Date'])

# %%
dfRemovals2 = df2_titled.loc[
  (df2_titled["Departed Date"] >= "2025-01-01") &
  (df2_titled["Departed Date"] <= "2025-12-31") &
  (df2_titled["State"] == "NEW YORK")
]

# %%
dfRemovals2
# Out:
# 5      Departed Date                                Port of Departure  \
# 72        2025-12-02            ALEXANDRIA INTERNATIONAL AIRPORT, POE
# 156       2025-11-16            ALEXANDRIA INTERNATIONAL AIRPORT, POE
# 260       2025-12-09                      NEW YORK, NY (KENNEDY), POE
# 262       2025-11-11                                 EL PASO, TX, POE
# 838       2025-12-30  MIAMI INTERNATIONAL AIRPORT, MIAMI FLORIDA, POE
# ...              ...                                              ...
# 184418    2025-11-13                             PORT ISABEL, TX, POE
# 184855    2025-10-07            ALEXANDRIA INTERNATIONAL AIRPORT, POE
# 185076    2025-12-08                          PASO DEL NORTE, TX, POE
# 185239    2025-12-23            ALEXANDRIA INTERNATIONAL AIRPORT, POE
# 185299    2025-12-08                                 PHOENIX, AZ, POE
#
# 5        Departure Country                              Case AOR     State  \
# ...

# %%
dfRemovals2.to_csv('FilteredData/All2025ICERemovals.csv', index=False)

# %%
df3 = pd.read_excel('/Users/sajinashrestha/Documents/dataProjects/WAMC/ICEpresense-CapitalRegion/RawData/Removals/2026-ICLI-00005_Removals_FY24_20260311_Redacted.xlsx')
df3
# Out:
#                        ERO LESA Statistical Tracking Unit  \
# 0             For Official Use Only (FOUO)/Pre-decisional
# 1       Deportation Data Project - 2026-ICLI-00005 – 0...
# 2                                                     NaN
# 3                                                     NaN
# 4                                     ICE Removals FY2024
# ...                                                   ...
# 343030                                2024-09-27 00:00:00
# 343031                                2024-09-28 00:00:00
# 343032                                2024-09-30 00:00:00
# 343033                                2024-07-31 00:00:00
# 343034                                2023-11-29 00:00:00
#
#                           Unnamed: 1 Unnamed: 2  \
# 0                                NaN        NaN
# 1                                NaN        NaN
# 2                                NaN        NaN
# 3                                NaN        NaN
# ...

# %%
df3 = df3.iloc[5:]
df3
# Out:
#        ERO LESA Statistical Tracking Unit                    Unnamed: 1  \
# 5                           Departed Date             Port of Departure
# 6                     2024-02-03 00:00:00            CHAMPLAIN, NY, POE
# 7                     2024-06-26 00:00:00          SAN ANTONIO, TX, POE
# 8                     2023-12-31 00:00:00          LOS ANGELES, CA, POE
# 9                     2024-02-23 00:00:00              MCALLEN, TX, POE
# ...                                   ...                           ...
# 343030                2024-09-27 00:00:00  BROWNSVILLE-MATAMOR, TX, POE
# 343031                2024-09-28 00:00:00  BROWNSVILLE-MATAMOR, TX, POE
# 343032                2024-09-30 00:00:00          BROWNSVILLE, TX, POE
# 343033                2024-07-31 00:00:00               LAREDO, TX, POE
# 343034                2023-11-29 00:00:00       PASO DEL NORTE, TX, POE
#
#                Unnamed: 2                            Unnamed: 3 Unnamed: 4  \
# ...

# %%
df3.columns = df3.iloc[0]
df3_titled = df3[1:].reset_index(drop=True)
df3_titled
# Out:
# 5             Departed Date             Port of Departure Departure Country  \
# 0       2024-02-03 00:00:00            CHAMPLAIN, NY, POE            CANADA
# 1       2024-06-26 00:00:00          SAN ANTONIO, TX, POE          HONDURAS
# 2       2023-12-31 00:00:00          LOS ANGELES, CA, POE            CANADA
# 3       2024-02-23 00:00:00              MCALLEN, TX, POE          HONDURAS
# 4       2024-04-25 00:00:00              DEL RIO, TX, POE            MEXICO
# ...                     ...                           ...               ...
# 343024  2024-09-27 00:00:00  BROWNSVILLE-MATAMOR, TX, POE            MEXICO
# 343025  2024-09-28 00:00:00  BROWNSVILLE-MATAMOR, TX, POE            MEXICO
# 343026  2024-09-30 00:00:00          BROWNSVILLE, TX, POE            MEXICO
# 343027  2024-07-31 00:00:00               LAREDO, TX, POE            MEXICO
# 343028  2023-11-29 00:00:00       PASO DEL NORTE, TX, POE            MEXICO
#
# ...

# %%
df3_titled['Departed Date'] = pd.to_datetime(df3_titled['Departed Date'])

# %%
dfRemovals3 = df3_titled.loc[
  (df3_titled["Departed Date"] >= "2025-01-01") &
  (df3_titled["Departed Date"] <= "2025-12-31")
]

# %%
dfRemovals3
# Out:
# Empty DataFrame
# Columns: [Departed Date, Port of Departure, Departure Country, Case AOR, State, County, Case Status, Gender, Birth Country, Citizenship Country, Birth Date, Birth Year, Entry Date, Entry Status, Known Terrorist Yes No, Suspected Gang Yes No, MSC Charge, MSC Charge Date, MSC Criminal Charge Status, MSC Charge Code, MSC Conviction Date, Case Criminality, Case Threat Level, Aggravated Felon Yes No, Processing Disposition, Case Category, Final Program, Final Program Code, Arresting Agency, TOA Case Category, Latest Apprehension Final Program, Latest Arresting Agency, Latest Apprehension Date, Final Order Yes No, Final Order Date, Final Charge Code, Final Charge Section, Prior Deport Yes No, Anonymized Identifier]
# Index: []
#
# [0 rows x 39 columns]

# %%
pdList = [dfRemovals1, dfRemovals2]
df_Removals2025 = pd.concat(pdList).drop_duplicates()
df_Removals2025
# Out:
# 5        Apprehension Date Apprehension Type     State County  \
# 14     2025-09-16 08:33:41        Collateral  NEW YORK    NaN
# 43     2025-01-28 12:26:00               NaN  NEW YORK    NaN
# 52     2025-07-25 11:29:25               NaN  NEW YORK    NaN
# 70     2025-06-09 13:03:41               NaN  NEW YORK    NaN
# 99     2025-09-12 14:29:15          Targeted  NEW YORK    NaN
# ...                    ...               ...       ...    ...
# 184814 2025-10-21 08:34:15        Collateral  NEW YORK    NaN
# 185156 2025-10-31 07:20:00        Collateral  NEW YORK    NaN
# 186543 2025-12-03 10:26:19          Targeted  NEW YORK    NaN
# 186642 2025-12-04 17:20:00        Collateral  NEW YORK    NaN
# 189191 2025-12-28 20:40:32        Collateral  NEW YORK    NaN
#
# 5                       TOA Current Duty AOR   Apprehension Final Program  \
# 14             Boston Area of Responsibility          Fugitive Operations
# ...

# %%
df_Arrests2025.to_csv('FilteredData/All2025ICEArrests.csv', index=False)
