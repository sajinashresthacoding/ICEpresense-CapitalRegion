# %% [markdown]
# ### In this notebook I will:
# pull data from arrests the year 2025 for NY

# %% [markdown]
# #### Arrests pull

# %%
## import necessary libraries
import pandas as pd

# %%
from datetime import datetime

# %%
df1 = pd.read_excel('/Users/sajinashrestha/Documents/dataProjects/WAMC/ICEpresense-CapitalRegion/RawData/Arrests/2026-ICLI-00005_Arrests_FY25_20260311_Redacted.xlsx')
df1
# Out:
#                        ERO LESA Statistical Tracking Unit  Unnamed: 1  \
# 0             For Official Use Only (FOUO)/Pre-decisional         NaN
# 1       Deportation Data Project - 2026-ICLI-00005 - 0...         NaN
# 2                                                     NaN         NaN
# 3                                                     NaN         NaN
# 4                       ERO Administrative Arrests FY2025         NaN
# ...                                                   ...         ...
# 235144                                2025-09-30 16:58:11  Collateral
# 235145                                2025-09-30 19:52:05    Targeted
# 235146                                2025-09-30 20:09:40    Targeted
# 235147                                2025-09-30 20:32:00    Targeted
# 235148                                2025-08-19 12:38:00    Targeted
#
#         Unnamed: 2 Unnamed: 3                            Unnamed: 4  \
# ...

# %%
df1 = df1.iloc[5:]
df1
# Out:
#        ERO LESA Statistical Tracking Unit         Unnamed: 1      Unnamed: 2  \
# 5                       Apprehension Date  Apprehension Type           State
# 6                     2025-09-17 11:34:21           Targeted           TEXAS
# 7                     2025-07-15 12:35:19                NaN         INDIANA
# 8                     2025-09-19 15:18:01           Targeted    PENNSYLVANIA
# 9                     2025-01-26 14:49:00                NaN  NORTH CAROLINA
# ...                                   ...                ...             ...
# 235144                2025-09-30 16:58:11         Collateral           TEXAS
# 235145                2025-09-30 19:52:05           Targeted           TEXAS
# 235146                2025-09-30 20:09:40           Targeted      CALIFORNIA
# 235147                2025-09-30 20:32:00           Targeted      CALIFORNIA
# 235148                2025-08-19 12:38:00           Targeted        NEW YORK
#
# ...

# %%
df1.columns = df1.iloc[0]
df1_titled = df1[1:].reset_index(drop=True)
df1_titled
# Out:
# 5         Apprehension Date Apprehension Type           State County  \
# 0       2025-09-17 11:34:21          Targeted           TEXAS    NaN
# 1       2025-07-15 12:35:19               NaN         INDIANA    NaN
# 2       2025-09-19 15:18:01          Targeted    PENNSYLVANIA    NaN
# 3       2025-01-26 14:49:00               NaN  NORTH CAROLINA    NaN
# 4       2025-02-19 00:00:00               NaN          KANSAS    NaN
# ...                     ...               ...             ...    ...
# 235138  2025-09-30 16:58:11        Collateral           TEXAS    NaN
# 235139  2025-09-30 19:52:05          Targeted           TEXAS    NaN
# 235140  2025-09-30 20:09:40          Targeted      CALIFORNIA    NaN
# 235141  2025-09-30 20:32:00          Targeted      CALIFORNIA    NaN
# 235142  2025-08-19 12:38:00          Targeted        NEW YORK    NaN
#
# 5                       TOA Current Duty AOR   Apprehension Final Program  \
# ...

# %%
df1_titled['Apprehension Date'] = pd.to_datetime(df1_titled['Apprehension Date'])

# %%
df1_titled.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235143 entries, 0 to 235142
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Apprehension Date           235143 non-null  datetime64[ns]
#  1   Apprehension Type           56922 non-null   object
#  2   State                       209509 non-null  object
#  3   County                      0 non-null       object
#  4   TOA Current Duty AOR        233440 non-null  object
#  5   Apprehension Final Program  235143 non-null  object
#  6   Arresting Agency            235143 non-null  object
#  7   Apprehension Method         235143 non-null  object
#  8   Apprehension Criminality    235143 non-null  object
#  9   Case Status                 230257 non-null  object
#  10  Case Category               230257 non-null  object
#  11  Departure Country           188534 non-null  object
# ...

# %%
##disregard, Apprehension AOR is no longer there

# %%
print(dfArrests0['Fruit'].nunique())

# %%
#This gets arrests with New York area of responsibility and/or the state of NY
co_arrests = arrests[
    (arrests['Apprehension AOR'] == 'Denver Area of Responsibility') |
    (arrests['Apprehension State'] == 'Colorado') | (arrests['Apprehension State'] == 'Wyoming')
]
co_arrests.info()
# Out:
# 5        Apprehension Date Apprehension Type     State County  \
# 14     2025-09-16 08:33:41        Collateral  NEW YORK    NaN
# 43     2025-01-28 12:26:00               NaN  NEW YORK    NaN
# 52     2025-07-25 11:29:25               NaN  NEW YORK    NaN
# 70     2025-06-09 13:03:41               NaN  NEW YORK    NaN
# 99     2025-09-12 14:29:15          Targeted  NEW YORK    NaN
# ...                    ...               ...       ...    ...
# 232928 2025-06-18 14:47:00               NaN  NEW YORK    NaN
# 233100 2025-06-25 21:57:38               NaN  NEW YORK    NaN
# 233101 2025-06-25 22:57:16               NaN  NEW YORK    NaN
# 234948 2025-09-22 15:07:00          Targeted  NEW YORK    NaN
# 235142 2025-08-19 12:38:00          Targeted  NEW YORK    NaN
#
# 5                       TOA Current Duty AOR   Apprehension Final Program  \
# 14             Boston Area of Responsibility          Fugitive Operations
# ...

# %%
dfArrests1.to_csv('FilteredData/2025ICEArrests1.csv', index=False)

# %%
df2 = pd.read_excel('/Users/sajinashrestha/Documents/dataProjects/WAMC/ICEpresense-CapitalRegion/RawData/Arrests/2026-ICLI-00005_Arrests_FY26_20260311_Redacted.xlsx')
df2
# Out:
#                        ERO LESA Statistical Tracking Unit  Unnamed: 1  \
# 0             For Official Use Only (FOUO)/Pre-decisional         NaN
# 1       Deportation Data Project - 2026-ICLI-00005 - 0...         NaN
# 2                                                     NaN         NaN
# 3                                                     NaN         NaN
# 4       ERO Administrative Arrests FY2026YTD (10/01/20...         NaN
# ...                                                   ...         ...
# 191547                                2026-03-10 17:07:39  Collateral
# 191548                                2026-03-10 17:22:39  Collateral
# 191549                                2026-03-10 17:21:11  Collateral
# 191550                                2026-03-10 16:14:39  Collateral
# 191551                                2026-03-10 18:26:43         NaN
#
#        Unnamed: 2 Unnamed: 3                        Unnamed: 4  \
# ...

# %%
df2 = df2.iloc[5:]
df2
# Out:
#        ERO LESA Statistical Tracking Unit         Unnamed: 1 Unnamed: 2  \
# 5                       Apprehension Date  Apprehension Type      State
# 6                     2025-11-16 14:21:59           Targeted      TEXAS
# 7                     2025-11-05 14:29:30         Collateral      TEXAS
# 8                     2025-12-14 08:18:33           Targeted       UTAH
# 9                     2026-02-14 10:27:08           Targeted    FLORIDA
# ...                                   ...                ...        ...
# 191547                2026-03-10 17:07:39         Collateral      TEXAS
# 191548                2026-03-10 17:22:39         Collateral      TEXAS
# 191549                2026-03-10 17:21:11         Collateral      TEXAS
# 191550                2026-03-10 16:14:39         Collateral      TEXAS
# 191551                2026-03-10 18:26:43                NaN        NaN
#
#        Unnamed: 3                             Unnamed: 4  \
# ...

# %%
df2.columns = df2.iloc[0]
df2_titled = df2[1:].reset_index(drop=True)
df2_titled
# Out:
# 5         Apprehension Date Apprehension Type     State County  \
# 0       2025-11-16 14:21:59          Targeted     TEXAS    NaN
# 1       2025-11-05 14:29:30        Collateral     TEXAS    NaN
# 2       2025-12-14 08:18:33          Targeted      UTAH    NaN
# 3       2026-02-14 10:27:08          Targeted   FLORIDA    NaN
# 4       2025-11-19 07:44:46          Targeted  ILLINOIS    NaN
# ...                     ...               ...       ...    ...
# 191541  2026-03-10 17:07:39        Collateral     TEXAS    NaN
# 191542  2026-03-10 17:22:39        Collateral     TEXAS    NaN
# 191543  2026-03-10 17:21:11        Collateral     TEXAS    NaN
# 191544  2026-03-10 16:14:39        Collateral     TEXAS    NaN
# 191545  2026-03-10 18:26:43               NaN       NaN    NaN
#
# 5                        TOA Current Duty AOR   Apprehension Final Program  \
# 0          San Antonio Area of Responsibility   ERO Criminal Alien Program
# ...

# %%
df2_titled['Apprehension Date'] = pd.to_datetime(df2_titled['Apprehension Date'])

# %%
dfArrests2 = df2_titled.loc[
  (df2_titled["Apprehension Date"] >= "2025-01-01") &
  (df2_titled["Apprehension Date"] <= "2025-12-31") &
  (df2_titled["State"] == "NEW YORK")
]

# %%
dfArrests2
# Out:
# 5        Apprehension Date Apprehension Type     State County  \
# 150    2025-11-11 07:00:00        Collateral  NEW YORK    NaN
# 167    2025-12-17 09:30:47          Targeted  NEW YORK    NaN
# 228    2025-11-03 09:00:00          Targeted  NEW YORK    NaN
# 260    2025-11-17 12:40:00        Collateral  NEW YORK    NaN
# 271    2025-12-05 09:59:03        Collateral  NEW YORK    NaN
# ...                    ...               ...       ...    ...
# 184814 2025-10-21 08:34:15        Collateral  NEW YORK    NaN
# 185156 2025-10-31 07:20:00        Collateral  NEW YORK    NaN
# 186543 2025-12-03 10:26:19          Targeted  NEW YORK    NaN
# 186642 2025-12-04 17:20:00        Collateral  NEW YORK    NaN
# 189191 2025-12-28 20:40:32        Collateral  NEW YORK    NaN
#
# 5                       TOA Current Duty AOR   Apprehension Final Program  \
# 150     New York City Area of Responsibility          Fugitive Operations
# ...

# %%
dfArrests2.to_csv('FilteredData/2025ICEArrests2.csv', index=False)

# %%
pdList = [dfArrests1, dfArrests2]
df_Arrests2025 = pd.concat(pdList).drop_duplicates()
df_Arrests2025
# Out:
# 5        Apprehension Date Apprehension Type     State County  \
# 14     2025-09-16 08:33:41        Collateral  NEW YORK    NaN
# 43     2025-01-28 12:26:00               NaN  NEW YORK    NaN
# 52     2025-07-25 11:29:25               NaN  NEW YORK    NaN
# 70     2025-06-09 13:03:41               NaN  NEW YORK    NaN
# 99     2025-09-12 14:29:15          Targeted  NEW YORK    NaN
# ...                    ...               ...       ...    ...
# 184814 2025-10-21 08:34:15        Collateral  NEW YORK    NaN
# 185156 2025-10-31 07:20:00        Collateral  NEW YORK    NaN
# 186543 2025-12-03 10:26:19          Targeted  NEW YORK    NaN
# 186642 2025-12-04 17:20:00        Collateral  NEW YORK    NaN
# 189191 2025-12-28 20:40:32        Collateral  NEW YORK    NaN
#
# 5                       TOA Current Duty AOR   Apprehension Final Program  \
# 14             Boston Area of Responsibility          Fugitive Operations
# ...

# %%
df_Arrests2025.to_csv('FilteredData/All2025ICEArrests.csv', index=False)
