# %%
import pandas as pd

# %%
pip install pyarrow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.7/32.7 MB 18.3 MB/s  0:00:01 18.7 MB/s eta 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_parquet('/Users/sajinashrestha/Documents/dataProjects/WAMC/ICEpresense-CapitalRegion/RawData/arrests-latest.parquet')

# %%
df
# Out:
#        apprehension_date apprehension_type apprehension_state  \
# 0             2022-10-01              None              TEXAS
# 1             2022-10-01              None               None
# 2             2022-10-01              None               None
# 3             2022-10-01              None            FLORIDA
# 4             2022-10-01              None              TEXAS
# ...                  ...               ...                ...
# 713459        2026-03-10          Targeted         NEW JERSEY
# 713460        2026-03-10          Targeted              TEXAS
# 713461        2026-03-10          Targeted         NEW JERSEY
# 713462        2026-03-11          Targeted         NEW JERSEY
# 713463        2026-09-17          Targeted              TEXAS
#
#                           apprehension_aor                final_program  \
# 0       San Antonio Area of Responsibility  Non-Detained Docket Control
# 1           Phoenix Area of Responsibility      Detained Docket Control
# ...

# %%
from datetime import datetime

# %%
df["apprehension_date"] = pd.to_datetime(df["apprehension_date"])

# %%
##siphoning jsut arrests made in nystate in the year of 2025

dfArrests = df.loc[
  (df["apprehension_date"] >= "2025-01-01") &
  (df["apprehension_date"] <= "2025-12-31") &
  (df["apprehension_state"] == "NEW YORK")
]

dfArrests
# Out:
#        apprehension_date apprehension_type apprehension_state  \
# 313423        2025-01-02              None           NEW YORK
# 313442        2025-01-02              None           NEW YORK
# 313449        2025-01-02              None           NEW YORK
# 313458        2025-01-02              None           NEW YORK
# 313467        2025-01-02              None           NEW YORK
# ...                  ...               ...                ...
# 634847        2025-12-31        Collateral           NEW YORK
# 634879        2025-12-31          Targeted           NEW YORK
# 634964        2025-12-31          Targeted           NEW YORK
# 634968        2025-12-31          Targeted           NEW YORK
# 634969        2025-12-31          Targeted           NEW YORK
#
#                             apprehension_aor                final_program  \
# 313423        Buffalo Area of Responsibility   ERO Criminal Alien Program
# ...

# %%
dfArrests.to_csv('FilteredData/2025NYArrests_062326.csv', index = False)
